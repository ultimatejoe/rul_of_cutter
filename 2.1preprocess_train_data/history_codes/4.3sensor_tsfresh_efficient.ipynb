# %% [markdown]
# tsfresh提取特征

# %%
import joblib
import pandas as pd
import numpy as np
from tsfresh import select_features
from tsfresh import extract_features
from tsfresh.feature_extraction import EfficientFCParameters
from tsfresh.feature_extraction import ComprehensiveFCParameters
from joblib import Parallel, delayed
import os

# %%
efficient_parameters = {
    'length': None,
    'abs_energy': None,
    
     'standard_deviation': None,
     'cid_ce': [{'normalize': True}, {'normalize': False}],
     'ar_coefficient': [{'coeff': 1, 'k': 10}],
     'fft_aggregated': [{'aggtype': 'centroid'},
                          {'aggtype': 'kurtosis'}],
    'quantile': [{'q': 0.1},
                  {'q': 0.2},
                  {'q': 0.3},
                  {'q': 0.4},
                  {'q': 0.6},
                  {'q': 0.7},
                  {'q': 0.8},
                  {'q': 0.9}],
     'autocorrelation': [
                  {'lag': 6},
                  {'lag': 7},
                  {'lag': 8},
                  {'lag': 9}],

    'agg_autocorrelation': [ {'f_agg': 'median'}],
    'approximate_entropy': [{'m': 2, 'r': 0.1},
                            {'m': 2, 'r': 0.3},
                            {'m': 2, 'r': 0.5},
                            {'m': 2, 'r': 0.7},
                            {'m': 2, 'r': 0.9}],

    'linear_trend': [{'attr': 'pvalue'},
                    {'attr': 'rvalue'},
                    {'attr': 'intercept'},
                    {'attr': 'slope'},
                    {'attr': 'stderr'}],
    
}

settings = efficient_parameters

# %%
def gen_tsfresh_feature_basis(sensor,settings):
    '''
    描述：
        settings，使用tsfresh提取指定特征
    参数：
        sensor：
        settings(dict): 想要提取的特征
    '''
    if 'vibration_1' in settings.keys():
        extracted_features = extract_features(sensor, column_id='id', column_sort='sort_col', n_jobs=48, 
                                          kind_to_fc_parameters=settings, disable_progressbar = True)
    else:
        extracted_features = extract_features(sensor, column_id='id', column_sort='sort_col', n_jobs=48, 
                                          default_fc_parameters=settings, disable_progressbar = False)
    return extracted_features

# %%
def gen_tsfresh_feature_parallel(train_no, csv_nos, settings):
    '''
    描述：
        并行提取多个senosr文件的tsfresh特征
    参数：
        train_no：第几个plc
        csv_nos：plc对应的sensor文件个数
    '''
    
    input_dir = './sensors_scale_cur/%s/'%train_no
    output_dir = './sensor_tsfresh_efficient/%s/'%train_no
    
    if not os.path.exists('./sensor_tsfresh_efficient'):
        os.mkdir('./sensor_tsfresh_efficient')
    if not os.path.exists('./sensor_tsfresh_efficient/%s'%train_no):
        os.mkdir('./sensor_tsfresh_efficient/%s'%train_no)
    
    def basis_func(idx):
        sensor = joblib.load(input_dir + '%d.lz4'%idx)
        tmp = gen_tsfresh_feature_basis(sensor, settings)
        joblib.dump(tmp, output_dir+'%d.lz4'%idx, compress='lz4')
        
    Parallel(n_jobs=1,verbose=1)(delayed(basis_func)(i) for i in range(1,csv_nos+1))

# %%
gen_tsfresh_feature_parallel('01', 48, settings)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
#
# Feature Extraction:   0%|          | 0/234 [00:00<?, ?it/s]
# Feature Extraction:   0%|          | 1/234 [00:17<1:08:45, 17.70s/it]
# Feature Extraction:   1%|▏         | 3/234 [00:17<22:53,  5.95s/it]
# Feature Extraction:   2%|▏         | 5/234 [00:17<13:42,  3.59s/it]
# Feature Extraction:   3%|▎         | 6/234 [00:18<11:32,  3.04s/it]
# Feature Extraction:   4%|▍         | 10/234 [00:18<06:56,  1.86s/it]
# Feature Extraction:   5%|▌         | 12/234 [00:18<05:50,  1.58s/it]
# Feature Extraction:   6%|▌         | 14/234 [00:19<04:59,  1.36s/it]
# Feature Extraction:   7%|▋         | 16/234 [00:19<04:21,  1.20s/it]
# Feature Extraction:   8%|▊         | 19/234 [00:19<03:38,  1.02s/it]
# Feature Extraction:   9%|▉         | 21/234 [00:19<03:18,  1.07it/s]
# Feature Extraction:  10%|▉         | 23/234 [00:19<03:02,  1.16it/s]
# Feature Extraction:  11%|█         | 25/234 [00:20<02:49,  1.23it/s]
# Feature Extraction:  12%|█▏        | 27/234 [00:20<02:36,  1.32it/s]
# Feature Extraction:  12%|█▏        | 29/234 [00:21<02:28,  1.38it/s]
# Feature Extraction:  13%|█▎        | 30/234 [00:21<02:24,  1.41it/s]
# Feature Extraction:  13%|█▎        | 31/234 [00:21<02:19,  1.45it/s]
# Feature Extraction:  14%|█▎        | 32/234 [00:21<02:15,  1.49it/s]
# Feature Extraction:  14%|█▍        | 33/234 [00:21<02:12,  1.52it/s]
# Feature Extraction:  15%|█▍        | 34/234 [00:22<02:10,  1.54it/s]
# Feature Extraction:  15%|█▍        | 35/234 [00:22<02:07,  1.56it/s]
# Feature Extraction:  16%|█▌        | 37/234 [00:22<02:01,  1.62it/s]
# Feature Extraction:  16%|█▌        | 38/234 [00:23<02:00,  1.62it/s]
# Feature Extraction:  17%|█▋        | 39/234 [00:23<01:57,  1.66it/s]
# Feature Extraction:  17%|█▋        | 40/234 [00:23<01:55,  1.68it/s]
# Feature Extraction:  18%|█▊        | 41/234 [00:23<01:52,  1.71it/s]
# Feature Extraction:  18%|█▊        | 42/234 [00:25<01:55,  1.67it/s]
# Feature Extraction:  18%|█▊        | 43/234 [00:25<01:54,  1.67it/s]
# Feature Extraction:  20%|█▉        | 46/234 [00:25<01:46,  1.77it/s]
# Feature Extraction:  20%|██        | 47/234 [00:27<01:50,  1.69it/s]
# Feature Extraction:  21%|██        | 48/234 [00:28<01:49,  1.71it/s]
# Feature Extraction:  21%|██        | 49/234 [00:33<02:08,  1.44it/s]
# Feature Extraction:  21%|██▏       | 50/234 [00:34<02:07,  1.44it/s]
# Feature Extraction:  22%|██▏       | 51/234 [00:34<02:04,  1.46it/s]
# Feature Extraction:  22%|██▏       | 52/234 [00:34<02:02,  1.49it/s]
# Feature Extraction:  23%|██▎       | 53/234 [00:35<02:01,  1.49it/s]
# Feature Extraction:  23%|██▎       | 54/234 [00:35<01:58,  1.51it/s]
# Feature Extraction:  24%|██▍       | 56/234 [00:35<01:53,  1.56it/s]
# Feature Extraction:  24%|██▍       | 57/234 [00:36<01:52,  1.58it/s]
# Feature Extraction:  25%|██▌       | 59/234 [00:36<01:49,  1.60it/s]
# Feature Extraction:  26%|██▌       | 61/234 [00:37<01:45,  1.64it/s]
# Feature Extraction:  27%|██▋       | 64/234 [00:37<01:40,  1.70it/s]
# Feature Extraction:  28%|██▊       | 65/234 [00:38<01:38,  1.71it/s]
# Feature Extraction:  29%|██▊       | 67/234 [00:38<01:35,  1.75it/s]
# Feature Extraction:  29%|██▉       | 68/234 [00:38<01:33,  1.77it/s]
# Feature Extraction:  30%|██▉       | 70/234 [00:38<01:30,  1.81it/s]
# Feature Extraction:  30%|███       | 71/234 [00:39<01:29,  1.82it/s]
# Feature Extraction:  31%|███       | 72/234 [00:39<01:28,  1.83it/s]
# Feature Extraction:  31%|███       | 73/234 [00:39<01:27,  1.85it/s]
# Feature Extraction:  32%|███▏      | 75/234 [00:39<01:24,  1.89it/s]
# Feature Extraction:  32%|███▏      | 76/234 [00:41<01:25,  1.84it/s]
# Feature Extraction:  33%|███▎      | 78/234 [00:41<01:22,  1.89it/s]
# Feature Extraction:  34%|███▍      | 79/234 [00:41<01:21,  1.91it/s]
# Feature Extraction:  34%|███▍      | 80/234 [00:41<01:20,  1.92it/s]
# Feature Extraction:  35%|███▍      | 81/234 [00:41<01:19,  1.93it/s]
# Feature Extraction:  35%|███▌      | 82/234 [00:42<01:18,  1.95it/s]
# Feature Extraction:  35%|███▌      | 83/234 [00:42<01:17,  1.96it/s]
# Feature Extraction:  36%|███▌      | 84/234 [00:42<01:16,  1.96it/s]
# Feature Extraction:  36%|███▋      | 85/234 [00:43<01:16,  1.94it/s]
# Feature Extraction:  37%|███▋      | 86/234 [00:44<01:15,  1.95it/s]
# Feature Extraction:  37%|███▋      | 87/234 [00:44<01:14,  1.97it/s]
# Feature Extraction:  38%|███▊      | 88/234 [00:44<01:14,  1.96it/s]
# Feature Extraction:  38%|███▊      | 89/234 [00:45<01:13,  1.97it/s]
# Feature Extraction:  38%|███▊      | 90/234 [00:46<01:14,  1.93it/s]
# Feature Extraction:  39%|███▉      | 91/234 [00:46<01:13,  1.94it/s]
# Feature Extraction:  39%|███▉      | 92/234 [00:47<01:13,  1.94it/s]
# Feature Extraction:  40%|███▉      | 93/234 [00:47<01:12,  1.95it/s]
# Feature Extraction:  40%|████      | 94/234 [00:48<01:11,  1.95it/s]
# Feature Extraction:  41%|████      | 95/234 [00:50<01:13,  1.89it/s]
# Feature Extraction:  41%|████      | 96/234 [00:50<01:12,  1.90it/s]
# Feature Extraction:  41%|████▏     | 97/234 [00:51<01:12,  1.89it/s]
# Feature Extraction:  42%|████▏     | 98/234 [00:52<01:12,  1.87it/s]
# Feature Extraction:  42%|████▏     | 99/234 [00:52<01:11,  1.88it/s]
# Feature Extraction:  43%|████▎     | 101/234 [00:52<01:09,  1.91it/s]
# Feature Extraction:  44%|████▎     | 102/234 [00:53<01:09,  1.91it/s]
# Feature Extraction:  44%|████▍     | 103/234 [00:53<01:08,  1.92it/s]
# Feature Extraction:  44%|████▍     | 104/234 [00:53<01:07,  1.93it/s]
# Feature Extraction:  45%|████▍     | 105/234 [00:53<01:06,  1.95it/s]
# Feature Extraction:  45%|████▌     | 106/234 [00:54<01:06,  1.94it/s]
# Feature Extraction:  46%|████▌     | 107/234 [00:55<01:05,  1.94it/s]
# Feature Extraction:  47%|████▋     | 109/234 [00:55<01:03,  1.96it/s]
# Feature Extraction:  47%|████▋     | 110/234 [00:55<01:02,  1.98it/s]
# Feature Extraction:  47%|████▋     | 111/234 [00:55<01:01,  1.99it/s]
# Feature Extraction:  48%|████▊     | 112/234 [00:56<01:01,  1.99it/s]
# Feature Extraction:  48%|████▊     | 113/234 [00:56<01:00,  2.00it/s]
# Feature Extraction:  49%|████▊     | 114/234 [00:56<00:59,  2.00it/s]
# Feature Extraction:  49%|████▉     | 115/234 [00:57<00:59,  2.02it/s]
# Feature Extraction:  50%|█████     | 118/234 [00:57<00:56,  2.06it/s]
# Feature Extraction:  51%|█████     | 119/234 [00:57<00:55,  2.08it/s]
# Feature Extraction:  51%|█████▏    | 120/234 [00:57<00:54,  2.08it/s]
# Feature Extraction:  52%|█████▏    | 122/234 [00:57<00:53,  2.11it/s]
# Feature Extraction:  53%|█████▎    | 123/234 [00:59<00:53,  2.07it/s]
# Feature Extraction:  53%|█████▎    | 124/234 [00:59<00:53,  2.08it/s]
# Feature Extraction:  53%|█████▎    | 125/234 [00:59<00:52,  2.09it/s]
# Feature Extraction:  54%|█████▍    | 126/234 [01:00<00:51,  2.08it/s]
# Feature Extraction:  54%|█████▍    | 127/234 [01:00<00:51,  2.09it/s]
# Feature Extraction:  55%|█████▍    | 128/234 [01:01<00:50,  2.09it/s]
# Feature Extraction:  55%|█████▌    | 129/234 [01:01<00:50,  2.09it/s]
# Feature Extraction:  56%|█████▌    | 130/234 [01:02<00:49,  2.10it/s]
# Feature Extraction:  56%|█████▌    | 131/234 [01:02<00:49,  2.09it/s]
# Feature Extraction:  56%|█████▋    | 132/234 [01:03<00:48,  2.09it/s]
# Feature Extraction:  57%|█████▋    | 134/234 [01:03<00:47,  2.11it/s]
# Feature Extraction:  58%|█████▊    | 135/234 [01:04<00:47,  2.09it/s]
# Feature Extraction:  58%|█████▊    | 136/234 [01:06<00:47,  2.05it/s]
# Feature Extraction:  59%|█████▊    | 137/234 [01:06<00:47,  2.06it/s]
# Feature Extraction:  59%|█████▉    | 139/234 [01:06<00:45,  2.09it/s]
# Feature Extraction:  60%|█████▉    | 140/234 [01:07<00:45,  2.07it/s]
# Feature Extraction:  60%|██████    | 141/234 [01:09<00:45,  2.03it/s]
# Feature Extraction:  61%|██████    | 143/234 [01:09<00:44,  2.06it/s]
# Feature Extraction:  62%|██████▏   | 144/234 [01:09<00:43,  2.06it/s]
# Feature Extraction:  62%|██████▏   | 145/234 [01:10<00:43,  2.06it/s]
# Feature Extraction:  62%|██████▏   | 146/234 [01:10<00:42,  2.06it/s]
# Feature Extraction:  63%|██████▎   | 148/234 [01:11<00:41,  2.07it/s]
# Feature Extraction:  64%|██████▎   | 149/234 [01:11<00:40,  2.08it/s]
# Feature Extraction:  64%|██████▍   | 150/234 [01:11<00:40,  2.09it/s]
# Feature Extraction:  65%|██████▍   | 151/234 [01:11<00:39,  2.10it/s]
# Feature Extraction:  65%|██████▍   | 152/234 [01:12<00:39,  2.10it/s]
# Feature Extraction:  65%|██████▌   | 153/234 [01:13<00:38,  2.09it/s]
# Feature Extraction:  66%|██████▌   | 154/234 [01:13<00:38,  2.10it/s]
# Feature Extraction:  67%|██████▋   | 157/234 [01:13<00:36,  2.13it/s]
# Feature Extraction:  68%|██████▊   | 158/234 [01:13<00:35,  2.14it/s]
# Feature Extraction:  68%|██████▊   | 159/234 [01:15<00:35,  2.12it/s]
# Feature Extraction:  68%|██████▊   | 160/234 [01:15<00:34,  2.13it/s]
# Feature Extraction:  69%|██████▉   | 161/234 [01:15<00:34,  2.13it/s]
# Feature Extraction:  71%|███████   | 165/234 [01:15<00:31,  2.18it/s]
# Feature Extraction:  71%|███████   | 166/234 [01:15<00:31,  2.19it/s]
# Feature Extraction:  71%|███████▏  | 167/234 [01:15<00:30,  2.20it/s]
# Feature Extraction:  72%|███████▏  | 168/234 [01:16<00:29,  2.20it/s]
# Feature Extraction:  73%|███████▎  | 170/234 [01:16<00:28,  2.22it/s]
# Feature Extraction:  73%|███████▎  | 171/234 [01:18<00:28,  2.18it/s]
# Feature Extraction:  74%|███████▎  | 172/234 [01:18<00:28,  2.19it/s]
# Feature Extraction:  74%|███████▍  | 173/234 [01:19<00:28,  2.17it/s]
# Feature Extraction:  75%|███████▍  | 175/234 [01:19<00:26,  2.19it/s]
# Feature Extraction:  75%|███████▌  | 176/234 [01:20<00:26,  2.19it/s]
# Feature Extraction:  76%|███████▌  | 177/234 [01:20<00:25,  2.19it/s]
# Feature Extraction:  76%|███████▌  | 178/234 [01:22<00:25,  2.17it/s]
# Feature Extraction:  76%|███████▋  | 179/234 [01:22<00:25,  2.17it/s]
# Feature Extraction:  77%|███████▋  | 180/234 [01:22<00:24,  2.17it/s]
# Feature Extraction:  78%|███████▊  | 182/234 [01:23<00:23,  2.19it/s]
# Feature Extraction:  78%|███████▊  | 183/234 [01:24<00:23,  2.17it/s]
# Feature Extraction:  79%|███████▊  | 184/234 [01:25<00:23,  2.16it/s]
# Feature Extraction:  79%|███████▉  | 186/234 [01:26<00:22,  2.15it/s]
# Feature Extraction:  80%|███████▉  | 187/234 [01:27<00:21,  2.15it/s]
# Feature Extraction:  80%|████████  | 188/234 [01:27<00:21,  2.15it/s]
# Feature Extraction:  81%|████████  | 189/234 [01:27<00:20,  2.16it/s]
# Feature Extraction:  81%|████████  | 190/234 [01:27<00:20,  2.16it/s]
# Feature Extraction:  82%|████████▏ | 191/234 [01:28<00:19,  2.17it/s]
# Feature Extraction:  82%|████████▏ | 192/234 [01:28<00:19,  2.17it/s]
# Feature Extraction:  82%|████████▏ | 193/234 [01:29<00:19,  2.15it/s]
# Feature Extraction:  83%|████████▎ | 195/234 [01:29<00:17,  2.17it/s]
# Feature Extraction:  85%|████████▍ | 198/234 [01:30<00:16,  2.19it/s]
# Feature Extraction:  85%|████████▌ | 199/234 [01:30<00:16,  2.19it/s]
# Feature Extraction:  86%|████████▌ | 201/234 [01:31<00:15,  2.20it/s]
# Feature Extraction:  87%|████████▋ | 203/234 [01:31<00:14,  2.21it/s]
# Feature Extraction:  88%|████████▊ | 205/234 [01:31<00:13,  2.23it/s]
# Feature Extraction:  88%|████████▊ | 206/234 [01:32<00:12,  2.23it/s]
# Feature Extraction:  88%|████████▊ | 207/234 [01:32<00:12,  2.24it/s]
# Feature Extraction:  90%|█████████ | 211/234 [01:32<00:10,  2.27it/s]
# Feature Extraction:  91%|█████████ | 212/234 [01:33<00:09,  2.28it/s]
# Feature Extraction:  92%|█████████▏| 216/234 [01:33<00:07,  2.32it/s]
# Feature Extraction:  93%|█████████▎| 218/234 [01:33<00:06,  2.33it/s]
# Feature Extraction:  94%|█████████▍| 220/234 [01:34<00:06,  2.32it/s]
# Feature Extraction:  95%|█████████▍| 222/234 [01:35<00:05,  2.33it/s]
# Feature Extraction:  95%|█████████▌| 223/234 [01:35<00:04,  2.34it/s]
# Feature Extraction:  96%|█████████▌| 225/234 [01:35<00:03,  2.36it/s]
# Feature Extraction:  97%|█████████▋| 227/234 [01:36<00:02,  2.36it/s]
# Feature Extraction:  97%|█████████▋| 228/234 [01:36<00:02,  2.37it/s]
# Feature Extraction:  98%|█████████▊| 230/234 [01:36<00:01,  2.39it/s]
# Feature Extraction:  99%|█████████▊| 231/234 [01:36<00:01,  2.39it/s]
# Feature Extraction:  99%|█████████▉| 232/234 [01:37<00:00,  2.39it/s]
# Feature Extraction: 100%|█████████▉| 233/234 [01:37<00:00,  2.40it/s]
# Feature Extraction: 100%|██████████| 234/234 [01:37<00:00,  2.40it/s]
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.7min remaining:    0.0s
#
# Feature Extraction:   0%|          | 0/239 [00:00<?, ?it/s]Process ForkPoolWorker-361:
# Process ForkPoolWorker-382:
# Process ForkPoolWorker-371:
# Process ForkPoolWorker-378:
# Process ForkPoolWorker-345:
# Process ForkPoolWorker-347:
# Process ForkPoolWorker-343:
# Process ForkPoolWorker-373:
# Process ForkPoolWorker-381:
# Process ForkPoolWorker-379:
# Traceback (most recent call last):
# Process ForkPoolWorker-341:
# Process ForkPoolWorker-340:
# Process ForkPoolWorker-359:
# Process ForkPoolWorker-338:
# Process ForkPoolWorker-339:
# Process ForkPoolWorker-344:
# Process ForkPoolWorker-380:
# Process ForkPoolWorker-366:
# Process ForkPoolWorker-367:
# Process ForkPoolWorker-363:
# Process ForkPoolWorker-349:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     719             try:
# --> 720                 item = self._items.popleft()
#     721             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-95fdee8de4c2> in <module>()
# ----> 1 gen_tsfresh_feature_parallel('01', 48, settings)
#
# <ipython-input-20-62750863612c> in gen_tsfresh_feature_parallel(train_no, csv_nos, settings)
#      21         joblib.dump(tmp, output_dir+'%d.lz4'%idx, compress='lz4')
#      22
# ---> 23     Parallel(n_jobs=1,verbose=10)(delayed(basis_func)(i) for i in range(1,csv_nos+1))
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# <ipython-input-20-62750863612c> in basis_func(idx)
#      18     def basis_func(idx):
#      19         sensor = joblib.load(input_dir + '%d.lz4'%idx)
# ---> 20         tmp = gen_tsfresh_feature_basis(sensor, settings)
#      21         joblib.dump(tmp, output_dir+'%d.lz4'%idx, compress='lz4')
#      22
#
# <ipython-input-19-b995c99a1b38> in gen_tsfresh_feature_basis(sensor, settings)
#      12     else:
#      13         extracted_features = extract_features(sensor, column_id='id', column_sort='sort_col', n_jobs=48,
# ---> 14                                           default_fc_parameters=settings, disable_progressbar = False)
#      15     return extracted_features
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor)
#     150                                 default_fc_parameters=default_fc_parameters,
#     151                                 kind_to_fc_parameters=kind_to_fc_parameters,
# --> 152                                 distributor=distributor)
#     153
#     154         # Impute the result if requested
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in _do_extraction(df, column_id, column_value, column_kind, default_fc_parameters, kind_to_fc_parameters, n_jobs, chunk_size, disable_progressbar, distributor)
#     231     kwargs = dict(default_fc_parameters=default_fc_parameters, kind_to_fc_parameters=kind_to_fc_parameters)
#     232     result = distributor.map_reduce(_do_extraction_on_chunk, data=data_in_chunks, chunk_size=chunk_size,
# --> 233                                     function_kwargs=kwargs)
#     234     distributor.close()
#     235
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py in map_reduce(self, map_function, data, function_kwargs, chunk_size, data_length)
#     147             result = self.distribute(_function_with_partly_reduce, chunk_generator, map_kwargs),
#     148
# --> 149         result = list(itertools.chain.from_iterable(result))
#     150
#     151         return result
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     928 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     929
# --> 930             for obj in iterable:
#     931                 yield obj
#     932                 # Update and possibly print the progressbar.
#
# /usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     722                 if self._index == self._length:
#     723                     raise StopIteration
# --> 724                 self._cond.wait(timeout)
#     725                 try:
#     726                     item = self._items.popleft()
#
# /usr/local/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-357:
# Process ForkPoolWorker-350:
# Process ForkPoolWorker-374:
# Process ForkPoolWorker-348:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-342:
# Process ForkPoolWorker-355:
# Process ForkPoolWorker-370:
# Process ForkPoolWorker-346:
# Process ForkPoolWorker-335:
# Process ForkPoolWorker-372:
# Process ForkPoolWorker-362:
# Process ForkPoolWorker-377:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-356:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-369:
# Traceback (most recent call last):
# Process ForkPoolWorker-351:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-353:
# Process ForkPoolWorker-354:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-360:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
# Traceback (most recent call last):
# Process ForkPoolWorker-376:
# Process ForkPoolWorker-352:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Process ForkPoolWorker-368:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 285, in _f
#     result = [("", func(data))]
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 38, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1606, in _phi
#     C = np.sum(np.max(np.abs(x_re[:, np.newaxis] - x_re[np.newaxis, :]),
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
# Process ForkPoolWorker-336:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
# Process ForkPoolWorker-337:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/distribution.py", line 37, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
# Process ForkPoolWorker-364:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 539, in standard_deviation
#     return np.std(x)
# Traceback (most recent call last):
# Process ForkPoolWorker-375:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
# ...
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4291, in percentile
#     interpolation=interpolation)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/home/shenjw/.local/lib/python3.6/site-packages/pandas/core/internals.py", line 1646, in quantile
#     result = _nanpercentile(values, qs * 100, axis=axis, **kw)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 293, in _do_extraction_on_chunk
#     return list(_f())
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2957, in mean
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1606, in _phi
#     C = np.sum(np.max(np.abs(x_re[:, np.newaxis] - x_re[np.newaxis, :]),
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4291, in percentile
#     interpolation=interpolation)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1606, in _phi
#     C = np.sum(np.max(np.abs(x_re[:, np.newaxis] - x_re[np.newaxis, :]),
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4033, in _ureduce
#     r = func(a, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1606, in _phi
#     C = np.sum(np.max(np.abs(x_re[:, np.newaxis] - x_re[np.newaxis, :]),
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/home/shenjw/.local/lib/python3.6/site-packages/pandas/core/internals.py", line 1586, in _nanpercentile
#     mask = isna(self.values)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 280, in _f
#     result = func(data, param=parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 287, in _f
#     for key, item in result:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 280, in _f
#     result = func(data, param=parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 70, in _mean
#     ret = umr_sum(arr, axis, dtype, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1606, in _phi
#     C = np.sum(np.max(np.abs(x_re[:, np.newaxis] - x_re[np.newaxis, :]),
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4033, in _ureduce
#     r = func(a, **kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4311, in _percentile
#     if q[i] < 0. or q[i] > 100.:
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
# KeyboardInterrupt
#   File "/home/shenjw/.local/lib/python3.6/site-packages/pandas/core/dtypes/missing.py", line 45, in isna
#     return _isna(obj)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1080, in linear_trend
#     linReg = linregress(range(len(x)), x)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py", line 283, in <genexpr>
#     result = ((convert_to_output_format(param), func(data, **param)) for param in parameter_list)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1203, in ar_coefficient
#     calculated_ar_params[k] = calculated_AR.fit(maxlag=k, solver="mle").params
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 4395, in _percentile
#     ap = np.moveaxis(ap, axis, 0)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
# KeyboardInterrupt
#   File "/home/shenjw/.local/lib/python3.6/site-packages/pandas/core/dtypes/missing.py", line 58, in _isna_new
#     return _isna_ndarraylike(obj)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py", line 93, in linregress
#     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1610, in approximate_entropy
#     return np.abs(_phi(m) - _phi(m + 1))
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1605, in _phi
#     x_re = np.array([x[i:i+m] for i in range(N - m + 1)])
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1607, in _phi
#     axis=2) <= r, axis=0) / (N-m+1)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/ar_model.py", line 555, in fit
#     arfit = OLS(Y, X).fit()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py", line 1582, in moveaxis
#     result = transpose(order)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/home/shenjw/.local/lib/python3.6/site-packages/pandas/core/dtypes/missing.py", line 153, in _isna_ndarraylike
#     result = np.isnan(values)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py", line 3103, in cov
#     X -= avg[:, None]
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1606, in _phi
#     C = np.sum(np.max(np.abs(x_re[:, np.newaxis] - x_re[np.newaxis, :]),
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/feature_calculators.py", line 1605, in <listcomp>
#     x_re = np.array([x[i:i+m] for i in range(N - m + 1)])
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 2320, in amax
#     out=out, **kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py", line 279, in fit
#     self.rank = np_matrix_rank(np.diag(singular_values))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 26, in _amax
#     return umr_maximum(a, axis, None, out, keepdims)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py", line 1647, in matrix_rank
#     return count_nonzero(S > tol, axis=-1)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py", line 421, in count_nonzero
#     return a_bool.sum(axis=axis, dtype=np.intp)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 32, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims)
# KeyboardInterrupt

# %%
gen_tsfresh_feature_parallel('02', 48 , settings)

# %%
gen_tsfresh_feature_parallel('03', 37, settings)

# %%
import joblib 
import pandas as pd
import numpy as np
from itertools import zip_longest
import os
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_sensor_byid(df, start, end):
    '''
    描述：
        绘制Sensor的Current_1，Vibration_1的图像
    '''
    plt.figure(figsize=(16,6))
    f = (df['id']>=start)&(df['id']<end)

    plt.subplot(1,2,1)
    df.loc[f,'Current_1'].plot()
    plt.title('Current_1')

    plt.subplot(1,2,2)
    df.loc[f,'Vibration_1'].plot()
    plt.title('Vibration_1')

def plot_sensor(test_no):
    df = joblib.load('../2.2preprocess_test_data/concats_more/concat_0%d.lz4'%test_no)
    plt.figure(figsize=(16,6))

    plt.subplot(1,2,1)
    df.loc[:,'Current_1__mean'].plot()
    plt.title('Current_1__mean')

    plt.subplot(1,2,2)
    df.loc[:,'Vibration_1__mean'].plot()
    plt.title('Vibration_1__mean')
    
def plot_plc_bycsv_no(plc, start, end):
    '''
    描述：
        绘制plc的图像
    '''
    cond = (plc['csv_no']>=start)&(plc['csv_no']<end)
    plc.loc[cond, ['spindle_load','x','y','z']].plot()

# %% [markdown]
# # 1.sensor_01

# %%
plc_01 = joblib.load('../../刀具剩余寿命预测_新数据/2.2preprocess_test_data/test_plc/test_01_plc.lz4')

# %%
plot_plc_bycsv_no(plc_01, 1, 10)

# %%
# 压缩后的sensor数据
plot_sensor(1)

# %%
sensor_01_1 = joblib.load('../2.2preprocess_test_data/sensors/01/1.lz4')
plot_sensor_byid(sensor_01_1, 1,2500)

# %%
sensor_01_9 = joblib.load('../2.2preprocess_test_data/sensors/01/9.lz4')
plot_sensor_byid(sensor_01_9, 1,2500)

# %% [markdown]
# # 2.sensor_02

# %%
plc_02 = joblib.load('../../刀具剩余寿命预测_新数据/2.2preprocess_test_data/test_plc/test_02_plc.lz4')

# %%
plot_plc_bycsv_no(plc_02, 1, 10)

# %%
plot_sensor(2)

# %% [markdown]
# # 3.sensor_03

# %%
plc_03 = joblib.load('../../刀具剩余寿命预测_新数据/2.2preprocess_test_data/test_plc/test_03_plc.lz4')

# %%
plot_plc_bycsv_no(plc_03, 1, 10)

# %%
plot_sensor(3)

# %% [markdown]
# # 4.sensor_04

# %%
plc_04 = joblib.load('../../刀具剩余寿命预测_新数据/2.2preprocess_test_data/test_plc/test_04_plc.lz4')

# %%
plot_plc_bycsv_no(plc_04, 1, 10)

# %%
plot_sensor(4)

# %% [markdown]
# # 5.sensor_05

# %%
plc_05 = joblib.load('../../刀具剩余寿命预测_新数据/2.2preprocess_test_data/test_plc/test_05_plc.lz4')

# %%
plot_plc_bycsv_no(plc_05, 1, 10)

# %%
plot_sensor(5)
